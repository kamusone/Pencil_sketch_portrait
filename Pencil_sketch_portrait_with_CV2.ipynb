# %% [markdown]
# <a href="https://colab.research.google.com/github/kamusone/Pencil_sketch_portrait/blob/master/Pencil_sketch_portrait_with_CV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
from google.colab.patches import cv2_imshow
import cv2

# %%
img=cv2.imread("/content/drive/My Drive/Colab Notebooks/09.png")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=632x632 at 0x7FAAC47686D8>

# %%
 img_gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=632x632 at 0x7FAABA6D20B8>

# %%
img_invert=cv2.bitwise_not(img_gray)

# %%
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=632x632 at 0x7FAABA6D2128>

# %%
img_smoothing=cv2.GaussianBlur(img_invert,(21,21),sigmaX=0,sigmaY=0)

# %%
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=632x632 at 0x7FAABA6D51D0>

# %%
def dodgeV2(x,y):
  return cv2.divide(x,255-y,scale=256)

# %%
final_img=dodgeV2(img_gray,img_smoothing)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=632x632 at 0x7FAABA6D2A20>
